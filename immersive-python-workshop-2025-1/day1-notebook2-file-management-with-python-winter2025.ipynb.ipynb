# %% [markdown]
# # Introduction - Python for File Management

# %% [markdown]
# **Goals:**
#
# *   Be able to navigate around the file system
# *   Indentify specific files
# *   Request file metadata
# *   Open and write metadata to CSV file

# %% [markdown]
# **Python Libraries:**
#
# [os - Operating System](https://docs.python.org/3/library/os.html)
#
#
# *   os.walk
# *   os.lisdir
# *   [os.path](https://docs.python.org/3/library/os.path.html)
#
#
#
# [time - Time Access and Conversion](https://docs.python.org/3/library/time.html?highlight=time#module-time)
#
#
# [csv - CSV File Reading and Writing](https://docs.python.org/3/library/csv.html)
#
# [pandas - Data Analysis](https://pandas.pydata.org/)

# %% [markdown]
# ## OS Library
#
# The OS library is a python package that allows you to interface with your computer's operating system. This library has a variety of modules that can enable you to access information on files and manipulate them for desired effects.
#
# For the purpose of this workshop, we will be using the OS library to navigate around Google colab's file system, find specific files, and generate metadata from these files.

# %% [markdown]
# ### **Goal:** Identifying and Changing Current Directory

# %%
#import os library
import os

#Set the current working directory as directory
directory = os.getcwd()

print(directory)
# Out:
# /content

# %%
#Change working directory to desired directory
os.chdir("/content/sample_data")

directory = os.getcwd()

print(directory)
# Out:
# /content/sample_data

# %% [markdown]
# ### Os.walk
#
# This is an application of the OS Library that produces a list of file names in a directory tree by "walking" it from top to bottom, or optionally in reverse. It is used in a for loop and yeilds a 3-tuple of dirpath, dirnames, filenames.
#
#
#
# **dirpath:** the path of the directory returned as a string
#
# **dirnames:** the names of the subdirectories returned as a list
#
# **filenames:** the name of non-directory files in the directory path returned as a list

# %%
#Write for loop to walk the /content directory
for root, dirs, files in os.walk("/content", topdown=True):

  print("Directory: " + root)

  #Notice that dirs has to be formatted as a string
  print("Subdirectories: " + (str(dirs)))

  print(files)
# Out:
# Directory: /content
# Subdirectories: ['.config', 'sample_data']
# []
# Directory: /content/.config
# Subdirectories: ['configurations', 'logs']
# ['.last_opt_in_prompt.yaml', 'default_configs.db', 'active_config', '.last_survey_prompt.yaml', 'gce', '.last_update_check.json', 'config_sentinel', 'hidden_gcloud_config_universe_descriptor_data_cache_configs.db']
# Directory: /content/.config/configurations
# Subdirectories: []
# ['config_default']
# Directory: /content/.config/logs
# Subdirectories: ['2025.01.07']
# []
# Directory: /content/.config/logs/2025.01.07
# Subdirectories: []
# ['14.21.40.150993.log', '14.21.52.061884.log', '14.21.29.466863.log', '14.21.09.201668.log', '14.21.41.175006.log', '14.21.52.691187.log']
# Directory: /content/sample_data
# Subdirectories: ['.ipynb_checkpoints']
# ['anscombe.json', 'README.md', 'mnist_test.CSV', 'california_housing_test.csv', 'california_housing_train.csv', 'mnist_train_small.csv']
# Directory: /content/sample_data/.ipynb_checkpoints
# Subdirectories: []
# []

# %% [markdown]
# ### Challenge
#
# Change your current working directory to the "web" directory in "datalab" and walk it.
#
# Print your current directory and each subdirectory.

# %%
#Start your code here
os.chdir("/datalab/web")

directory = os.getcwd()

print(directory)

for root, dirs, files in os.walk(directory, topdown=True):

  print("Subdirectories: " + str(dirs))
# Out:
# /datalab/web
# Subdirectories: ['pyright', 'node_modules', 'lsp', 'config']
# Subdirectories: ['typeshed-fallback']
# Subdirectories: ['stubs', 'stdlib']
# Subdirectories: ['editdistance', 'pyvmomi', 'docutils', 'redis', 'contextvars', 'termcolor', 'chardet', 'pyaudio', 'flake8-plugin-utils', 'playsound', 'flake8-typing-imports', 'regex', 'annoy', 'SQLAlchemy', 'pynput', 'Markdown', 'ldap3', 'tabulate', 'flake8-builtins', 'humanfriendly', 'colorama', 'pyOpenSSL', 'openpyxl', 'google-cloud-ndb', 'html5lib', 'babel', 'vobject', 'Flask-SQLAlchemy', 'Send2Trash', 'gdb', 'bleach', 'prettytable', 'entrypoints', 'six', 'python-dateutil', 'xxhash', 'python-nmap', 'boto', 'typed-ast', 'appdirs', 'Pillow', 'stdlib-list', 'setuptools', 'pycurl', 'mysqlclient', 'tqdm', 'flake8-rst-docstrings', 'PyYAML', 'pyflakes', 'pyRFC3339', 'whatthepatch', 'protobuf', 'passlib', 'cachetools', 'python-slugify', 'ttkthemes', 'selenium', 'xmltodict', 'polib', 'aws-xray-sdk', 'backports.ssl_match_hostname', 'passpy', 'first', 'stripe', 'paramiko', 'croniter', 'pytz', 'tzlocal', 'opentracing', 'JACK-Client', 'click-spinner', 'invoke', 'toposort', 'hdbcli', 'aiofiles', 'requests', 'commonmark', 'flake8-2020', 'fpdf2', 'Pygments', 'python-gflags', 'cryptography', 'mypy-extensions', 'Flask-Cors', 'DateTimeRange', 'slumber', 'docopt', 'Deprecated', 'braintree', 'chevron', 'freezegun', 'caldav', 'certifi', 'pysftp', 'python-jose', 'beautifulsoup4', 'atomicwrites', 'urllib3', 'PyMySQL', 'pep8-naming', 'httplib2', 'waitress', 'dj-database-url', 'pyfarmhash', 'psycopg2', 'flake8-docstrings', 'retry', 'ujson', 'emoji', 'simplejson', 'oauthlib', 'zxcvbn', 'pytest-lazy-fixture', 'singledispatch', 'psutil', 'flake8-bugbear', 'mock', 'jmespath', 'decorator', 'flake8-simplify', 'toml', 'parsimonious', 'dateparser', 'jsonschema']
# Subdirectories: ['editdistance']
# Subdirectories: []
# Subdirectories: ['pyVmomi']
# Subdirectories: ['vim', 'vmodl']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['docutils']
# Subdirectories: ['languages', 'parsers', 'writers', 'utils', 'transforms', 'readers']
# Subdirectories: []
# Subdirectories: ['rst']
# Subdirectories: ['directives']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['redis']
# Subdirectories: ['asyncio', 'commands']
# Subdirectories: []
# Subdirectories: ['bf', 'timeseries', 'search', 'json', 'graph']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['chardet']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['flake8_plugin_utils']
# Subdirectories: ['utils']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['regex']
# Subdirectories: []
# Subdirectories: ['annoy']
# Subdirectories: []
# Subdirectories: ['sqlalchemy']
# Subdirectories: ['pool', 'event', 'testing', 'future', 'ext', 'sql', 'engine', 'connectors', 'databases', 'util', 'dialects', 'orm']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['plugin']
# Subdirectories: []
# Subdirectories: ['orm']
# Subdirectories: []
# Subdirectories: ['declarative', 'asyncio', 'mypy']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['oracle', 'postgresql', 'mssql', 'sybase', 'mysql', 'sqlite', 'firebird']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['pynput']
# Subdirectories: ['keyboard', 'mouse']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['markdown']
# Subdirectories: ['extensions']
# Subdirectories: []
# Subdirectories: ['ldap3']
# Subdirectories: ['operation', 'strategy', 'protocol', 'extend', 'utils', 'core', 'abstract']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['sasl', 'schemas', 'formatters']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['standard', 'microsoft', 'novell']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['humanfriendly']
# Subdirectories: ['terminal']
# Subdirectories: []
# Subdirectories: ['colorama']
# Subdirectories: []
# Subdirectories: ['OpenSSL']
# Subdirectories: []
# Subdirectories: ['openpyxl']
# Subdirectories: ['comments', 'styles', 'descriptors', 'chart', 'compat', 'writer', 'utils', 'formatting', 'pivot', 'cell', 'xml', 'reader', 'drawing', 'workbook', 'formula', 'packaging', 'worksheet', 'chartsheet']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['external_link']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['google']
# Subdirectories: ['cloud']
# Subdirectories: ['ndb']
# Subdirectories: []
# Subdirectories: ['html5lib']
# Subdirectories: ['filters', 'treebuilders', 'treeadapters', 'treewalkers', '_trie']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['babel']
# Subdirectories: ['localtime', 'messages']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['vobject']
# Subdirectories: []
# Subdirectories: ['flask_sqlalchemy']
# Subdirectories: []
# Subdirectories: ['send2trash']
# Subdirectories: []
# Subdirectories: ['gdb']
# Subdirectories: []
# Subdirectories: ['bleach']
# Subdirectories: []
# Subdirectories: ['prettytable']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['six']
# Subdirectories: ['moves']
# Subdirectories: ['urllib']
# Subdirectories: []
# Subdirectories: ['dateutil']
# Subdirectories: ['tz', 'parser']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['xxhash']
# Subdirectories: []
# Subdirectories: ['nmap']
# Subdirectories: []
# Subdirectories: ['boto']
# Subdirectories: ['ec2', 'kms', 'elb', 's3']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['typed_ast']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['PIL']
# Subdirectories: []
# Subdirectories: ['stdlib_list']
# Subdirectories: []
# Subdirectories: ['pkg_resources', 'setuptools']
# Subdirectories: []
# Subdirectories: ['command', 'extern', '_distutils']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['command']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['MySQLdb']
# Subdirectories: ['constants']
# Subdirectories: []
# Subdirectories: ['tqdm']
# Subdirectories: ['contrib']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['yaml']
# Subdirectories: []
# Subdirectories: ['pyflakes']
# Subdirectories: []
# Subdirectories: ['pyrfc3339']
# Subdirectories: []
# Subdirectories: ['whatthepatch']
# Subdirectories: []
# Subdirectories: ['google']
# Subdirectories: ['protobuf']
# Subdirectories: ['internal', 'compiler', 'util']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['passlib']
# Subdirectories: ['ext', 'utils', 'crypto', 'handlers']
# Subdirectories: ['django']
# Subdirectories: []
# Subdirectories: ['compat']
# Subdirectories: []
# Subdirectories: ['scrypt', '_blowfish']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['cachetools']
# Subdirectories: []
# Subdirectories: ['slugify']
# Subdirectories: []
# Subdirectories: ['ttkthemes']
# Subdirectories: []
# Subdirectories: ['selenium']
# Subdirectories: ['common', 'webdriver']
# Subdirectories: []
# Subdirectories: ['firefox', 'ie', 'webkitgtk', 'chrome', 'phantomjs', 'blackberry', 'android', 'common', 'edge', 'support', 'safari', 'opera', 'remote']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['actions', 'html5']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['aws_xray_sdk']
# Subdirectories: ['core']
# Subdirectories: ['streaming', 'plugins', 'emitters', 'utils', 'models', 'sampling', 'exceptions']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['local']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['backports']
# Subdirectories: ['ssl_match_hostname']
# Subdirectories: []
# Subdirectories: ['passpy']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['stripe']
# Subdirectories: ['api_resources']
# Subdirectories: ['issuing', 'terminal', 'identity', 'radar', 'billing_portal', 'abstract', 'checkout', 'sigma', 'reporting']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['paramiko']
# Subdirectories: []
# Subdirectories: ['croniter']
# Subdirectories: []
# Subdirectories: ['pytz']
# Subdirectories: []
# Subdirectories: ['tzlocal']
# Subdirectories: []
# Subdirectories: ['opentracing']
# Subdirectories: ['ext', 'mocktracer', 'scope_managers', 'harness']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['jack']
# Subdirectories: []
# Subdirectories: ['click_spinner']
# Subdirectories: []
# Subdirectories: ['invoke']
# Subdirectories: ['parser', 'completion']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['hdbcli']
# Subdirectories: []
# Subdirectories: ['aiofiles']
# Subdirectories: ['threadpool', 'tempfile']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['requests']
# Subdirectories: []
# Subdirectories: ['commonmark']
# Subdirectories: ['render']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['fpdf']
# Subdirectories: []
# Subdirectories: ['pygments']
# Subdirectories: ['styles', 'lexers', 'filters', 'formatters']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['cryptography']
# Subdirectories: ['hazmat', 'x509']
# Subdirectories: ['primitives', 'backends', 'bindings']
# Subdirectories: ['serialization', 'asymmetric', 'kdf', 'ciphers', 'twofactor']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['openssl']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['flask_cors']
# Subdirectories: []
# Subdirectories: ['datetimerange']
# Subdirectories: []
# Subdirectories: ['slumber']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['deprecated']
# Subdirectories: []
# Subdirectories: ['braintree']
# Subdirectories: ['merchant_account', 'dispute_details', 'util', 'exceptions']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['http']
# Subdirectories: []
# Subdirectories: ['chevron']
# Subdirectories: []
# Subdirectories: ['freezegun']
# Subdirectories: []
# Subdirectories: ['caldav']
# Subdirectories: ['elements', 'lib']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['pysftp']
# Subdirectories: []
# Subdirectories: ['jose']
# Subdirectories: ['backends']
# Subdirectories: []
# Subdirectories: ['bs4']
# Subdirectories: ['builder']
# Subdirectories: []
# Subdirectories: ['atomicwrites']
# Subdirectories: []
# Subdirectories: ['urllib3']
# Subdirectories: ['packages', 'contrib', 'util']
# Subdirectories: ['ssl_match_hostname']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['pymysql']
# Subdirectories: ['constants']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['httplib2']
# Subdirectories: []
# Subdirectories: ['waitress']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['psycopg2']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['retry']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['emoji']
# Subdirectories: ['unicode_codes']
# Subdirectories: []
# Subdirectories: ['simplejson']
# Subdirectories: []
# Subdirectories: ['oauthlib']
# Subdirectories: ['openid', 'oauth2', 'oauth1']
# Subdirectories: ['connect']
# Subdirectories: ['core']
# Subdirectories: ['endpoints', 'grant_types']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['rfc6749']
# Subdirectories: ['endpoints', 'grant_types', 'clients']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['rfc5849']
# Subdirectories: ['endpoints']
# Subdirectories: []
# Subdirectories: ['zxcvbn']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['psutil']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['mock']
# Subdirectories: []
# Subdirectories: ['jmespath']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['flake8_simplify']
# Subdirectories: []
# Subdirectories: ['toml']
# Subdirectories: []
# Subdirectories: ['parsimonious']
# Subdirectories: []
# Subdirectories: ['dateparser_data', 'dateparser']
# Subdirectories: []
# Subdirectories: ['languages', 'data', 'utils', 'search', 'calendars']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['jsonschema']
# Subdirectories: []
# Subdirectories: ['pyexpat', 'email', 'urllib', '_typeshed', 'os', 'tkinter', 'dbm', 'zoneinfo', 'sqlite3', 'lib2to3', 'xmlrpc', 'curses', 'distutils', 'venv', 'msilib', 'collections', 'ctypes', 'unittest', 'json', 'asyncio', 'encodings', 'multiprocessing', 'xml', 'wsgiref', 'http', 'logging', 'pydoc_data', 'concurrent', 'importlib', 'ensurepip', 'html']
# Subdirectories: []
# Subdirectories: ['mime']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['pgen2']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['command']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['dummy']
# Subdirectories: []
# Subdirectories: ['dom', 'parsers', 'sax', 'etree']
# Subdirectories: []
# Subdirectories: ['expat']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['futures']
# Subdirectories: []
# Subdirectories: ['metadata']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['requires-port', 'engine.io', 'mime-types', 'minimist', 'safe-buffer', 'object-component', 'ms', 'socket.io', 'bunyan', 'async-limiter', 'base64-arraybuffer', 'ultron', 'negotiator', 'after', 'lodash', 'ncp', 'parseqs', 'accepts', 'socket.io-adapter', 'http-proxy', 'parseuri', 'inflight', 'engine.io-client', 'balanced-match', 'indexof', 'blob', 'inherits', 'xmlhttprequest-ssl', 'component-emitter', 'component-inherit', 'socket.io-parser', 'glob', 'has-binary2', 'arraybuffer.slice', 'to-array', 'bunyan-rotating-file-stream', 'brace-expansion', 'ws', 'wrappy', 'dtrace-provider', 'mv', 'concat-map', 'minimatch', '.bin', 'safe-json-stringify', 'callsite', 'mime-db', 'once', 'isarray', 'options', 'component-bind', 'nan', 'yeast', 'cookie', 'base64id', 'async', 'has-cors', 'debug', 'follow-redirects', 'mkdirp', 'engine.io-parser', 'semver', 'moment', 'socket.io-client', 'better-assert', 'backo2', 'strftime', 'path-is-absolute', 'eventemitter3', 'rimraf', 'node-pty']
# Subdirectories: []
# Subdirectories: ['node_modules', 'lib']
# Subdirectories: ['ws']
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: ['transports']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test', 'example']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: ['bin', 'lib', 'docs']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['img']
# Subdirectories: []
# Subdirectories: ['coverage']
# Subdirectories: ['lcov-report']
# Subdirectories: ['async-throttle']
# Subdirectories: []
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: []
# Subdirectories: ['fp']
# Subdirectories: []
# Subdirectories: ['test', 'bin', 'lib']
# Subdirectories: ['symlink-fixtures', 'modified-files', 'regular-fixtures']
# Subdirectories: ['src']
# Subdirectories: ['dir']
# Subdirectories: []
# Subdirectories: ['src', 'out']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['src']
# Subdirectories: ['sub']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['coverage', '.nyc_output', 'lib']
# Subdirectories: ['lcov-report']
# Subdirectories: ['http-proxy', 'lib']
# Subdirectories: ['passes']
# Subdirectories: []
# Subdirectories: ['http-proxy']
# Subdirectories: ['passes']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['http-proxy']
# Subdirectories: ['passes']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['node_modules', 'lib']
# Subdirectories: ['ws']
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: ['transports']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['tests', 'example', 'lib']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['.vscode', 'typings', 'lib', 'docs']
# Subdirectories: []
# Subdirectories: ['node']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['node_modules', 'lib']
# Subdirectories: ['ultron']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['libusdt', 'src', 'build']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['Release']
# Subdirectories: ['obj.target', '.deps']
# Subdirectories: []
# Subdirectories: ['Release']
# Subdirectories: ['obj.target']
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: ['a-folder']
# Subdirectories: ['another-folder']
# Subdirectories: []
# Subdirectories: ['test', 'example']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['.idea']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['doc', 'tools']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: ['lib', 'dist']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['src']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test', 'bin', 'examples']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['lib']
# Subdirectories: []
# Subdirectories: ['bin']
# Subdirectories: []
# Subdirectories: ['min', 'src', 'locale']
# Subdirectories: []
# Subdirectories: ['lib', 'locale']
# Subdirectories: ['duration', 'create', 'utils', 'format', 'parse', 'moment', 'units', 'locale']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['lib', 'dist']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['test']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['umd']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['node_modules', 'deps', 'src', 'scripts', 'typings', 'lib', 'build']
# Subdirectories: ['nan']
# Subdirectories: ['doc', 'tools']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['winpty']
# Subdirectories: ['misc', 'ship', 'src']
# Subdirectories: ['Font-Report-June2016']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['shared', 'agent', 'include', 'tests', 'libwinpty', 'unix-adapter', 'debugserver']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['unix', 'win']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []
# Subdirectories: ['Release']
# Subdirectories: []
# Subdirectories: []
# Subdirectories: []

# %% [markdown]
# ### **Goal:** List files and choose specific file formats

# %%
#Change current directory back to sample_data
os.chdir("/content/sample_data")

directory = os.getcwd()

#Write a for loop using os.listdir and print each file in directory
for file in os.listdir(directory):
  print(file)
# Out:
# anscombe.json
# README.md
# mnist_test.CSV
# .ipynb_checkpoints
# california_housing_test.csv
# california_housing_train.csv
# mnist_train_small.csv

# %%
#Let's say we only want to see the CSV files

#Add an IF statement to the loop to check file extension
for file in os.listdir(directory):

  #Checks if filename ends with .csv
  if file.endswith(".csv"):

    print(file)
# Out:
# california_housing_test.csv
# california_housing_train.csv
# mnist_train_small.csv

# %%
for file in os.listdir(directory):

  #Add .lower to statement
  if file.lower().endswith(".csv"):

    print(file)
# Out:
# mnist_test.CSV
# california_housing_test.csv
# california_housing_train.csv
# mnist_train_small.csv

# %% [markdown]
# ### **Goal:** Generate File Metadata
#
# Os.path: This module is used to interact with and manipulate pathnames

# %%
#We'll start with a for loop to begin our process
for file in os.listdir(directory):

  #We're going to continue with this IF statement to limit the files
  if file.lower().endswith(".csv"):

    #basename is used to return the base name of the pathname
    filename = os.path.basename(file)
    print("Filename: " + filename)

    #abspath is used to return a normalized absolutized version of the pathname
    filepath = os.path.abspath(file)
    print("File path: " + filepath)
# Out:
# Filename: mnist_test.CSV
# File path: /content/sample_data/mnist_test.CSV
# Filename: california_housing_test.csv
# File path: /content/sample_data/california_housing_test.csv
# Filename: california_housing_train.csv
# File path: /content/sample_data/california_housing_train.csv
# Filename: mnist_train_small.csv
# File path: /content/sample_data/mnist_train_small.csv

# %%
#Let's say that we want to the size of the files

for file in os.listdir(directory):

  if file.lower().endswith(".csv"):

    filename = os.path.basename(file)
    print("Filename: " + filename)

    #getsize is used the return the size of the file in bytes
    filesize = os.path.getsize(file)

    #Note that filesize needs to be formatted as an string
    print("File size: " + str(filesize) + " bytes")
# Out:
# Filename: mnist_test.CSV
# File size: 18289443 bytes
# Filename: california_housing_test.csv
# File size: 301141 bytes
# Filename: california_housing_train.csv
# File size: 1706430 bytes
# Filename: mnist_train_small.csv
# File size: 36523880 bytes

# %%
#Lastly, let's get when the file was created and when it was last modified

for file in os.listdir(directory):

  if file.lower().endswith(".csv"):

    filename = os.path.basename(file)

    #getctime returns when the file was created
    creation = os.path.getctime(file)

    #getmtime returns when the file was last modified
    modified = os.path.getmtime(file)

    print("Filename: " + filename)

    print("Created: " + str(creation))

    print("Last Modified: " + str(modified))
# Out:
# Filename: mnist_test.CSV
# Created: 1736436008.8889623
# Last Modified: 1736259726.0
# Filename: california_housing_test.csv
# Created: 1736262471.981379
# Last Modified: 1736259726.0
# Filename: california_housing_train.csv
# Created: 1736262471.9973805
# Last Modified: 1736259725.0
# Filename: mnist_train_small.csv
# Created: 1736262472.4814246
# Last Modified: 1736259726.0

# %% [markdown]
# getctime and getmtime return a value that is a floating point number giving the number of seconds since the Unix epoch. This being January 1, 1970, 00:00:00 (UTC).
#
# To make this easier to read, when can use the **time** module to convert those seconds. ctime is used to convert time expressed in seconds since the epoch to a string.

# %%
#import time library
import time

for file in os.listdir(directory):

  if file.lower().endswith(".csv"):

    filename = os.path.basename(file)

    creation = os.path.getctime(file)
    #use ctime to convert the creation time value and assign it to creation_time
    creation_time = time.ctime(creation)

    modified = os.path.getmtime(file)
    #use ctime to convert the modified time value and assign it to modified_time
    modified_time = time.ctime(modified)

    print("Filename: " + filename)

    print("Created: " + creation_time)

    print("Last Modified: " + modified_time)
# Out:
# Filename: mnist_test.CSV
# Created: Thu Jan  9 15:20:08 2025
# Last Modified: Tue Jan  7 14:22:06 2025
# Filename: california_housing_test.csv
# Created: Tue Jan  7 15:07:51 2025
# Last Modified: Tue Jan  7 14:22:06 2025
# Filename: california_housing_train.csv
# Created: Tue Jan  7 15:07:51 2025
# Last Modified: Tue Jan  7 14:22:05 2025
# Filename: mnist_train_small.csv
# Created: Tue Jan  7 15:07:52 2025
# Last Modified: Tue Jan  7 14:22:06 2025

# %% [markdown]
# ## Challenge
#
# Write a for loop to find the .json file in the directory and print its file path and when it was last accessed.
#
# os.path.getatime(path) is used to return when a path was last accessed.

# %%
#Start your code here
for file in os.listdir(directory):

  if file.lower().endswith(".json"):

    filepath = os.path.abspath(file)
    print("File path: " + filepath)

    access = os.path.getatime(file)
    access_time = time.ctime(access)
    print("Last accessed:" + access_time)
# Out:
# File path: /content/sample_data/anscombe.json
# Last accessed:Sat Jan  1 08:00:00 2000

# %% [markdown]
# ##  CSV Library
#
# The CSV library enables you to read and write data in CSV format. We will be using this library to create a new CSV file and writing the metadata that we generated to this new file.

# %% [markdown]
# So we can read the metadata csv file, we will be borrow a couple of lines of code from the PANDAS library.

# %%
#import csv library
import csv

#import pandas and assign it as pd
import pandas as pd

#file_metadata.csv will be the file that we create in the current directory
# 'w' sets the file as writeable
with open('file_metadata.csv', 'w') as csvfile:

  #used to convert data into delimited strings on the given file
  csvwriter = csv.writer(csvfile)

  #Create a list of strings that represent the catogeries we collected
  rows = ['Filename', 'Path', 'Test']

  #write the rows the csv file
  csvwriter.writerow(rows)

test = pd.read_csv('file_metadata.csv')

test
# Out:
# Empty DataFrame
# Columns: [Filename, Path, Test]
# Index: []

# %%
#import csv library
import csv

#import pandas and assign it as pd
import pandas as pd

#file_metadata.csv will be the file that we create in the current directory
# 'w' sets the file as writeable
with open('file_metadata.csv', 'w') as csvfile:

  #used to convert data into delimited strings on the given file
  csvwriter = csv.writer(csvfile)

  #Create a list of strings that represent the catogeries we collected
  rows = ['Filename', 'Path']

  #write the rows the csv file
  csvwriter.writerow(rows)

  #write for loop to process each file in directory
  for file in os.listdir(directory):

            filename = os.path.basename(file)

            path = os.path.abspath(file)

            #write each variable in its corresponding row
            csvwriter.writerow([filename, path])


test = pd.read_csv('file_metadata.csv')

test
# Out:
#                        Filename  \
# 0                 anscombe.json
# 1                     README.md
# 2                mnist_test.CSV
# 3             file_metadata.csv
# 4            .ipynb_checkpoints
# 5   california_housing_test.csv
# 6  california_housing_train.csv
# 7         mnist_train_small.csv
#
#                                                 Path
# 0                 /content/sample_data/anscombe.json
# 1                     /content/sample_data/README.md
# 2                /content/sample_data/mnist_test.CSV
# 3             /content/sample_data/file_metadata.csv
# 4            /content/sample_data/.ipynb_checkpoints
# 5   /content/sample_data/california_housing_test.csv
# 6  /content/sample_data/california_housing_train.csv
# 7         /content/sample_data/mnist_train_small.csv

# %% [markdown]
# ## Challenge
#
# Edit the above script to also record the size of each file and when they were created, last modified, and accessed.

# %%
#import csv library
import csv

#import pandas and assign it as pd
import pandas as pd

#file_metadata.csv will be the file that we create in the current directory
# 'w' sets the file as writeable
with open('file_metadata.csv', 'w') as csvfile:

  #used to convert data into delimited strings on the given file
  csvwriter = csv.writer(csvfile)

  #Create a list of strings that represent the catogeries we collected
  rows = ['Filename', 'Path', 'File Size', 'Created', 'Modified', 'Accessed']

  #write the rows the csv file
  csvwriter.writerow(rows)

  #write for loop to process each file in directory
  for file in os.listdir(directory):

            filename = os.path.basename(file)

            path = os.path.abspath(file)

            filesize = os.path.getsize(file)

            creation = os.path.getctime(file)
            creation_time = time.ctime(creation)

            modified = os.path.getmtime(file)
            modified_time = time.ctime(modified)

            access = os.path.getatime(file)
            access_time = time.ctime(access)

            #write each variable in its corresponding row
            csvwriter.writerow([filename, path, filesize, creation_time, modified_time, access_time])



test = pd.read_csv('file_metadata.csv')

test
# Out:
#                        Filename  \
# 0                 anscombe.json
# 1                     README.md
# 2                mnist_test.CSV
# 3             file_metadata.csv
# 4            .ipynb_checkpoints
# 5   california_housing_test.csv
# 6  california_housing_train.csv
# 7         mnist_train_small.csv
#
#                                                 Path  File Size  \
# 0                 /content/sample_data/anscombe.json       1697
# 1                     /content/sample_data/README.md        962
# 2                /content/sample_data/mnist_test.CSV   18289443
# 3             /content/sample_data/file_metadata.csv          0
# 4            /content/sample_data/.ipynb_checkpoints       4096
# 5   /content/sample_data/california_housing_test.csv     301141
# 6  /content/sample_data/california_housing_train.csv    1706430
# 7         /content/sample_data/mnist_train_small.csv   36523880
#
#                     Created                  Modified  \
# 0  Tue Jan  7 15:07:51 2025  Sat Jan  1 08:00:00 2000
# 1  Tue Jan  7 15:07:51 2025  Sat Jan  1 08:00:00 2000
# 2  Thu Jan  9 15:20:08 2025  Tue Jan  7 14:22:06 2025
# 3  Thu Jan  9 21:56:52 2025  Thu Jan  9 21:56:52 2025
# 4  Thu Jan  9 15:20:08 2025  Thu Jan  9 15:20:08 2025
# 5  Tue Jan  7 15:07:51 2025  Tue Jan  7 14:22:06 2025
# 6  Tue Jan  7 15:07:51 2025  Tue Jan  7 14:22:05 2025
# 7  Tue Jan  7 15:07:52 2025  Tue Jan  7 14:22:06 2025
#
#                    Accessed
# 0  Sat Jan  1 08:00:00 2000
# 1  Sat Jan  1 08:00:00 2000
# 2  Thu Jan  9 15:20:18 2025
# 3  Thu Jan  9 21:49:16 2025
# 4  Thu Jan  9 21:26:41 2025
# 5  Tue Jan  7 14:22:06 2025
# 6  Tue Jan  7 14:22:05 2025
# 7  Tue Jan  7 14:22:06 2025

# %% [markdown]
# # Installing Pandas Locally
#
# [PANDAS](https://pandas.pydata.org/) is a python data analysis library used for data manipulation and analysis.
#
# How to install locally:
#
# 1) Search for and open your command line
#
#
# *   For Mac Users: Terminal
# *   For PC User: Command Prompt
#
#
# 2) Check that you can run Python
#
#
# *   For Mac Users: python3 --version
# *   For PC Users: py --version
#
#
# 3) Check that you can run pip
#
#
# *   For Mac Users: python3 -m pip --version
# *   For PC Users: py -m pip --version
#
#
#
#
# 4) Pip install pandas
#
# *   For Mac Users: python3 -m pip install pandas
# *   For PC Users: py -m pip install pandas
