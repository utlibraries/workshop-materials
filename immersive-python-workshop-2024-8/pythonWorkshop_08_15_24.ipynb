# %% [markdown]
# # Introduction - Python for File Management

# %% [markdown]
# **Goals:**
#
# *   Be able to navigate around the file system
# *   Indentify specific files
# *   Request file metadata
# *   Open and write metadata to CSV file

# %% [markdown]
# **Python Libraries:**
#
# [os - Operating System](https://docs.python.org/3/library/os.html)
#
#
# *   os.walk
# *   os.lisdir
# *   [os.path](https://docs.python.org/3/library/os.path.html)
#
#
#
# [time - Time Access and Conversion](https://docs.python.org/3/library/time.html?highlight=time#module-time)
#
#
# [csv - CSV File Reading and Writing](https://docs.python.org/3/library/csv.html)
#
# [pandas - Data Analysis](https://pandas.pydata.org/)

# %% [markdown]
# ## OS Library
#
# The OS library is a python package that allows you to interface with your computers's operating system. This library has a variety of modules that can enable you to access information on files and manipulate them for desired effects.
#
# For the purpose of this workshop, we will be using the OS library to navigate around Google colab's file system, find specific files, and generate metadata from these files.

# %% [markdown]
# ### **Goal:** Identifying and Changing Current Directory

# %%
#import os library
import os

#Set the current working directory as directory
directory = os.getcwd()

print(directory)
# Out:
# /content

# %%
#Change working directory to desired directory
os.chdir("/content/sample_data")

directory = os.getcwd()

print(directory)
# Out:
# /content/sample_data

# %% [markdown]
# ### Os.walk
#
# This is an application of the OS Library that produces a list of file names in a directory tree by "walking" it from top to bottom, or optionally in reverse. It is used in a for loop and yeilds a 3-tuple of dirpath, dirnames, filenames.
#
#
#
# **dirpath:** the path of the directory returned as a string
#
# **dirnames:** the names of the subdirectories returned as a list
#
# **filenames:** the name of non-directory files in the directory path returned as a list

# %%
#Write for loop to walk the /content directory
for root, dirs, files in os.walk("/content", topdown=False):

  print("Directory: " + root)

  #Notice that dirs has to be formatted as a string
  print("Subdirectories: " + (str(dirs)))

  print(files)
# Out:
# Directory: /content/.config/logs/2024.08.13
# Subdirectories: []
# ['13.25.04.560730.log', '13.25.45.679285.log', '13.25.44.351490.log', '13.25.28.914591.log', '13.26.01.890863.log', '13.26.01.085715.log']
# Directory: /content/.config/logs
# Subdirectories: ['2024.08.13']
# []
# Directory: /content/.config/configurations
# Subdirectories: []
# ['config_default']
# Directory: /content/.config
# Subdirectories: ['logs', 'configurations']
# ['active_config', 'config_sentinel', '.last_survey_prompt.yaml', '.last_opt_in_prompt.yaml', 'gce', 'hidden_gcloud_config_universe_descriptor_data_cache_configs.db', '.last_update_check.json', 'default_configs.db']
# Directory: /content/sample_data/.ipynb_checkpoints
# Subdirectories: []
# []
# Directory: /content/sample_data
# Subdirectories: ['.ipynb_checkpoints']
# ['anscombe.json', 'README.md', 'mnist_test.CSV', 'california_housing_train.csv', 'mnist_train_small.csv', 'california_housing_test.csv']
# Directory: /content
# Subdirectories: ['.config', 'sample_data']
# []

# %% [markdown]
# ### Challenge
#
# Change your current working directory to the "web" directory in "datalab" and walk it.
#
# Print your current directory and each subdirectory.

# %%
#Start your code here
os.chdir("/datalab/web")

directory = os.getcwd()

for root, dirs, files in os.walk(directory, topdown=False):

  print(directory)

  print("Subdirectories: " + str(dirs))
# Out:
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['futures']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['expat']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['sax', 'dom', 'parsers', 'etree']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['dummy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['mime']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['pgen2']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['metadata']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['command']
# /datalab/web
# Subdirectories: ['concurrent', 'dbm', 'encodings', 'os', 'ctypes', 'xml', 'venv', 'pyexpat', 'tkinter', 'urllib', 'unittest', '_typeshed', 'html', 'multiprocessing', 'wsgiref', 'pydoc_data', 'collections', 'http', 'ensurepip', 'msilib', 'sqlite3', 'json', 'zoneinfo', 'curses', 'xmlrpc', 'logging', 'email', 'asyncio', 'lib2to3', 'importlib', 'distutils']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['cachetools']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['pysftp']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['ssl_match_hostname']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['util', 'packages', 'contrib']
# /datalab/web
# Subdirectories: ['urllib3']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['paramiko']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['passpy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['abstract', 'reporting', 'checkout', 'terminal', 'identity', 'billing_portal', 'issuing', 'sigma', 'radar']
# /datalab/web
# Subdirectories: ['api_resources']
# /datalab/web
# Subdirectories: ['stripe']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['chevron']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['completion', 'parser']
# /datalab/web
# Subdirectories: ['invoke']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['actions', 'html5']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['remote', 'phantomjs', 'opera', 'blackberry', 'support', 'common', 'webkitgtk', 'android', 'chrome', 'safari', 'ie', 'firefox', 'edge']
# /datalab/web
# Subdirectories: ['common', 'webdriver']
# /datalab/web
# Subdirectories: ['selenium']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['toml']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['yaml']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['render']
# /datalab/web
# Subdirectories: ['commonmark']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['constants']
# /datalab/web
# Subdirectories: ['pymysql']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['annoy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['gdb']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['zxcvbn']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['pytz']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['atomicwrites']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['mock']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['contrib']
# /datalab/web
# Subdirectories: ['tqdm']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['stdlib_list']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['bf', 'graph', 'timeseries', 'search', 'json']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['commands', 'asyncio']
# /datalab/web
# Subdirectories: ['redis']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['ssl_match_hostname']
# /datalab/web
# Subdirectories: ['backports']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['mocktracer', 'harness', 'scope_managers', 'ext']
# /datalab/web
# Subdirectories: ['opentracing']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['ttkthemes']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['freezegun']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['chardet']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['extensions']
# /datalab/web
# Subdirectories: ['markdown']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['novell', 'standard', 'microsoft']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['sasl', 'formatters', 'schemas']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['abstract', 'extend', 'protocol', 'operation', 'utils', 'strategy', 'core']
# /datalab/web
# Subdirectories: ['ldap3']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['flask_cors']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['deprecated']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['openssl']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['serialization', 'kdf', 'twofactor', 'ciphers', 'asymmetric']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['bindings', 'primitives', 'backends']
# /datalab/web
# Subdirectories: ['x509', 'hazmat']
# /datalab/web
# Subdirectories: ['cryptography']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['elb', 'ec2', 's3', 'kms']
# /datalab/web
# Subdirectories: ['boto']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['retry']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['jack']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['hdbcli']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['jmespath']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['utils']
# /datalab/web
# Subdirectories: ['flake8_plugin_utils']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['command']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['extern', '_distutils', 'command']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['setuptools', 'pkg_resources']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['slugify']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['_blowfish', 'scrypt']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['compat']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['django']
# /datalab/web
# Subdirectories: ['handlers', 'crypto', 'utils', 'ext']
# /datalab/web
# Subdirectories: ['passlib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['pyflakes']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['simplejson']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['local']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['streaming', 'utils', 'sampling', 'emitters', 'plugins', 'exceptions', 'models']
# /datalab/web
# Subdirectories: ['core']
# /datalab/web
# Subdirectories: ['aws_xray_sdk']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['colorama']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['internal', 'util', 'compiler']
# /datalab/web
# Subdirectories: ['protobuf']
# /datalab/web
# Subdirectories: ['google']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['pyrfc3339']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['tzlocal']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['click_spinner']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['send2trash']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['backends']
# /datalab/web
# Subdirectories: ['jose']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['tz', 'parser']
# /datalab/web
# Subdirectories: ['dateutil']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['jsonschema']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'elements']
# /datalab/web
# Subdirectories: ['caldav']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['vobject']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['parsimonious']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['httplib2']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['typed_ast']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['whatthepatch']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['prettytable']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['regex']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['flake8_simplify']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['mouse', 'keyboard']
# /datalab/web
# Subdirectories: ['pynput']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['terminal']
# /datalab/web
# Subdirectories: ['humanfriendly']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['xxhash']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['constants']
# /datalab/web
# Subdirectories: ['MySQLdb']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['treewalkers', 'treeadapters', 'treebuilders', '_trie', 'filters']
# /datalab/web
# Subdirectories: ['html5lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['psycopg2']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['data', 'languages', 'utils', 'search', 'calendars']
# /datalab/web
# Subdirectories: ['dateparser_data', 'dateparser']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['fpdf']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['editdistance']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['tempfile', 'threadpool']
# /datalab/web
# Subdirectories: ['aiofiles']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['croniter']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lexers', 'formatters', 'styles', 'filters']
# /datalab/web
# Subdirectories: ['pygments']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['nmap']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['vmodl', 'vim']
# /datalab/web
# Subdirectories: ['pyVmomi']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['ndb']
# /datalab/web
# Subdirectories: ['cloud']
# /datalab/web
# Subdirectories: ['google']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['slumber']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['unicode_codes']
# /datalab/web
# Subdirectories: ['emoji']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['OpenSSL']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['waitress']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['bleach']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['flask_sqlalchemy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['urllib']
# /datalab/web
# Subdirectories: ['moves']
# /datalab/web
# Subdirectories: ['six']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['datetimerange']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['builder']
# /datalab/web
# Subdirectories: ['bs4']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['orm']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['plugin']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['firebird', 'mssql', 'sqlite', 'postgresql', 'mysql', 'oracle', 'sybase']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['declarative', 'mypy', 'asyncio']
# /datalab/web
# Subdirectories: ['future', 'databases', 'event', 'util', 'testing', 'sql', 'pool', 'connectors', 'orm', 'engine', 'dialects', 'ext']
# /datalab/web
# Subdirectories: ['sqlalchemy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['directives']
# /datalab/web
# Subdirectories: ['rst']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['writers', 'languages', 'parsers', 'transforms', 'utils', 'readers']
# /datalab/web
# Subdirectories: ['docutils']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['psutil']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['http']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['merchant_account', 'util', 'exceptions', 'dispute_details']
# /datalab/web
# Subdirectories: ['braintree']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['localtime', 'messages']
# /datalab/web
# Subdirectories: ['babel']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['external_link']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['reader', 'xml', 'formula', 'cell', 'chartsheet', 'worksheet', 'packaging', 'writer', 'formatting', 'comments', 'utils', 'chart', 'styles', 'pivot', 'compat', 'workbook', 'descriptors', 'drawing']
# /datalab/web
# Subdirectories: ['openpyxl']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['requests']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['endpoints']
# /datalab/web
# Subdirectories: ['rfc5849']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['endpoints', 'grant_types', 'clients']
# /datalab/web
# Subdirectories: ['rfc6749']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['endpoints', 'grant_types']
# /datalab/web
# Subdirectories: ['core']
# /datalab/web
# Subdirectories: ['connect']
# /datalab/web
# Subdirectories: ['oauth1', 'oauth2', 'openid']
# /datalab/web
# Subdirectories: ['oauthlib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['PIL']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['cachetools', 'playsound', 'pysftp', 'certifi', 'urllib3', 'paramiko', 'passpy', 'stripe', 'chevron', 'pycurl', 'invoke', 'selenium', 'toml', 'mypy-extensions', 'flake8-rst-docstrings', 'PyYAML', 'commonmark', 'PyMySQL', 'annoy', 'gdb', 'zxcvbn', 'pytz', 'atomicwrites', 'mock', 'tqdm', 'stdlib-list', 'flake8-docstrings', 'redis', 'backports.ssl_match_hostname', 'opentracing', 'ttkthemes', 'freezegun', 'termcolor', 'chardet', 'toposort', 'Markdown', 'ldap3', 'polib', 'Flask-Cors', 'Deprecated', 'cryptography', 'boto', 'retry', 'JACK-Client', 'hdbcli', 'jmespath', 'flake8-plugin-utils', 'setuptools', 'python-slugify', 'passlib', 'pep8-naming', 'tabulate', 'pyflakes', 'simplejson', 'aws-xray-sdk', 'colorama', 'flake8-builtins', 'protobuf', 'docopt', 'pyRFC3339', 'tzlocal', 'click-spinner', 'appdirs', 'pyaudio', 'contextvars', 'Send2Trash', 'python-jose', 'python-dateutil', 'jsonschema', 'flake8-typing-imports', 'caldav', 'vobject', 'parsimonious', 'httplib2', 'typed-ast', 'whatthepatch', 'prettytable', 'ujson', 'regex', 'flake8-simplify', 'pynput', 'humanfriendly', 'xxhash', 'mysqlclient', 'html5lib', 'python-gflags', 'psycopg2', 'dateparser', 'fpdf2', 'editdistance', 'flake8-bugbear', 'aiofiles', 'xmltodict', 'croniter', 'Pygments', 'python-nmap', 'pyvmomi', 'google-cloud-ndb', 'slumber', 'emoji', 'pyOpenSSL', 'pyfarmhash', 'waitress', 'bleach', 'Flask-SQLAlchemy', 'pytest-lazy-fixture', 'six', 'DateTimeRange', 'beautifulsoup4', 'SQLAlchemy', 'docutils', 'decorator', 'psutil', 'braintree', 'entrypoints', 'babel', 'openpyxl', 'dj-database-url', 'flake8-2020', 'requests', 'oauthlib', 'Pillow', 'singledispatch', 'first']
# /datalab/web
# Subdirectories: ['stdlib', 'stubs']
# /datalab/web
# Subdirectories: ['typeshed-fallback']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'dist']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['example', 'test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['node_gyp_bins', 'Release']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['tools', 'doc']
# /datalab/web
# Subdirectories: ['nan']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['Font-Report-June2016']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['libwinpty', 'debugserver', 'unix-adapter', 'shared', 'agent', 'tests', 'include']
# /datalab/web
# Subdirectories: ['misc', 'ship', 'src']
# /datalab/web
# Subdirectories: ['winpty']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['win', 'unix']
# /datalab/web
# Subdirectories: ['lib', 'build', 'scripts', 'typings', 'node_modules', 'deps', 'src']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['node']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'typings', 'docs', '.vscode']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['transports']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: ['ws']
# /datalab/web
# Subdirectories: ['lib', 'node_modules']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['src']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['tools', 'doc']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['umd']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['another-folder']
# /datalab/web
# Subdirectories: ['a-folder']
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['transports']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: ['ws']
# /datalab/web
# Subdirectories: ['lib', 'node_modules']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'tests', 'example']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['img']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'docs', 'bin']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['.idea']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['async-throttle']
# /datalab/web
# Subdirectories: ['lcov-report']
# /datalab/web
# Subdirectories: ['coverage']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['example', 'test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['ultron']
# /datalab/web
# Subdirectories: ['lib', 'node_modules']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['fp']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'dist']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['bin', 'examples', 'test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['bin']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['passes']
# /datalab/web
# Subdirectories: ['http-proxy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['passes']
# /datalab/web
# Subdirectories: ['http-proxy']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['passes']
# /datalab/web
# Subdirectories: ['lib', 'http-proxy']
# /datalab/web
# Subdirectories: ['lcov-report']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'coverage', '.nyc_output']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['obj.target']
# /datalab/web
# Subdirectories: ['Release']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['.deps', 'obj.target']
# /datalab/web
# Subdirectories: ['node_gyp_bins', 'Release']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['build', 'libusdt', 'src']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['sub']
# /datalab/web
# Subdirectories: ['src']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['out', 'src']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['dir']
# /datalab/web
# Subdirectories: ['src']
# /datalab/web
# Subdirectories: ['regular-fixtures', 'modified-files', 'symlink-fixtures']
# /datalab/web
# Subdirectories: ['lib', 'bin', 'test']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['create', 'parse', 'utils', 'duration', 'format', 'locale', 'units', 'moment']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['lib', 'locale']
# /datalab/web
# Subdirectories: ['min', 'locale', 'src']
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: []
# /datalab/web
# Subdirectories: ['async', 'glob', 'balanced-match', 'options', 'indexof', 'callsite', 'better-assert', 'once', 'concat-map', 'node-pty', 'parseqs', 'mime-types', 'blob', 'inherits', 'bunyan-rotating-file-stream', 'to-array', 'safe-buffer', 'parseuri', 'engine.io-client', 'debug', 'component-bind', 'isarray', 'nan', 'eventemitter3', 'mv', 'has-binary2', 'engine.io', 'xmlhttprequest-ssl', 'bunyan', 'safe-json-stringify', 'async-limiter', 'mime-db', 'negotiator', 'backo2', 'arraybuffer.slice', 'base64-arraybuffer', 'minimist', 'ws', 'lodash', 'base64id', 'socket.io-client', 'object-component', 'path-is-absolute', 'ultron', 'cookie', 'mkdirp', 'component-emitter', 'inflight', 'semver', 'wrappy', 'after', 'yeast', 'engine.io-parser', 'socket.io-adapter', 'socket.io-parser', 'http-proxy', 'component-inherit', 'strftime', 'minimatch', 'socket.io', '.bin', 'ms', 'dtrace-provider', 'has-cors', 'ncp', 'rimraf', 'follow-redirects', 'moment', 'requires-port', 'brace-expansion', 'accepts']
# /datalab/web
# Subdirectories: ['pyright', 'config', 'lsp', 'node_modules']

# %% [markdown]
# ### **Goal:** List files and choose specific file types

# %%
#Change current directory back to sample_data
os.chdir("/content/sample_data")

directory = os.getcwd()

#Write a for loop using os.listdir and print each file in directory
for file in os.listdir(directory):
  print(file)
# Out:
# anscombe.json
# README.md
# mnist_test.CSV
# .ipynb_checkpoints
# california_housing_train.csv
# mnist_train_small.csv
# california_housing_test.csv

# %%
#Let's say we only want to see the CSV files

#Add an IF statement to the loop to check file extension
for file in os.listdir(directory):

  #Checks if filename ends with .csv
  if file.endswith(".csv"):

    print(file)
# Out:
# california_housing_train.csv
# mnist_train_small.csv
# california_housing_test.csv

# %%
for file in os.listdir(directory):

  #Add .lower to statement
  if file.lower().endswith(".csv"):

    print(file)
# Out:
# mnist_test.CSV
# california_housing_train.csv
# mnist_train_small.csv
# california_housing_test.csv

# %% [markdown]
# ### **Goal:** Generate File Metadata
#
# Os.path: This module is used to interact with and manipulate pathnames

# %%
#We'll start with a for loop to begin our process
for file in os.listdir(directory):

  #We're going to continue with this IF statement to limit the files
  if file.lower().endswith(".csv"):

    #basename is used to return the base name of the pathname
    filename = os.path.basename(file)
    print("Filename: " + filename)

    #abspath is used to return a normalized absolutized version of the pathname
    filepath = os.path.abspath(file)
    print("File path: " + filepath)
# Out:
# Filename: mnist_test.CSV
# File path: /content/sample_data/mnist_test.CSV
# Filename: california_housing_train.csv
# File path: /content/sample_data/california_housing_train.csv
# Filename: mnist_train_small.csv
# File path: /content/sample_data/mnist_train_small.csv
# Filename: california_housing_test.csv
# File path: /content/sample_data/california_housing_test.csv

# %%
#Let's say that we want to the size of the files

for file in os.listdir(directory):

  if file.lower().endswith(".csv"):

    filename = os.path.basename(file)
    print("Filename: " + filename)

    #getsize is used the return the size of the file in bytes
    filesize = os.path.getsize(file)

    #Note that filesize needs to be formatted as an string
    print("File size: " + str(filesize) + " bytes")
# Out:
# Filename: mnist_test.CSV
# File size: 18289443 bytes
# Filename: california_housing_train.csv
# File size: 1706430 bytes
# Filename: mnist_train_small.csv
# File size: 36523880 bytes
# Filename: california_housing_test.csv
# File size: 301141 bytes

# %%
#Lastly, let's get when the file was created and when it was last modified

for file in os.listdir(directory):

  if file.lower().endswith(".csv"):

    filename = os.path.basename(file)

    #getctime returns when the file was created
    creation = os.path.getctime(file)

    #getmtime returns when the file was last modified
    modified = os.path.getmtime(file)

    print("Filename: " + filename)

    print("Created: " + str(creation))

    print("Last Modified: " + str(modified))
# Out:
# Filename: mnist_test.CSV
# Created: 1723739856.2626855
# Last Modified: 1723555582.0
# Filename: california_housing_train.csv
# Created: 1723559364.6925225
# Last Modified: 1723555579.0
# Filename: mnist_train_small.csv
# Created: 1723559365.1175556
# Last Modified: 1723555581.0
# Filename: california_housing_test.csv
# Created: 1723559364.6795213
# Last Modified: 1723555579.0

# %% [markdown]
# getctime and getmtime return a value that is a floating point number giving the number of seconds since the Unix epoch. This being January 1, 1970, 00:00:00 (UTC).
#
# To make this easier to read, when can use the **time** module to convert those seconds. ctime is used to convert time expressed in seconds since the epoch to a string.

# %%
#import time library
import time

for file in os.listdir(directory):

  if file.lower().endswith(".csv"):

    filename = os.path.basename(file)

    creation = os.path.getctime(file)
    #use ctime to convert the creation time value and assign it to creation_time
    creation_time = time.ctime(creation)

    modified = os.path.getmtime(file)
    #use ctime to convert the modified time value and assign it to modified_time
    modified_time = time.ctime(modified)

    print("Filename: " + filename)

    print("Created: " + creation_time)

    print("Last Modified: " + modified_time)
# Out:
# Filename: mnist_test.CSV
# Created: Thu Aug 15 16:37:36 2024
# Last Modified: Tue Aug 13 13:26:22 2024
# Filename: california_housing_train.csv
# Created: Tue Aug 13 14:29:24 2024
# Last Modified: Tue Aug 13 13:26:19 2024
# Filename: mnist_train_small.csv
# Created: Tue Aug 13 14:29:25 2024
# Last Modified: Tue Aug 13 13:26:21 2024
# Filename: california_housing_test.csv
# Created: Tue Aug 13 14:29:24 2024
# Last Modified: Tue Aug 13 13:26:19 2024

# %% [markdown]
# ## Challenge
#
# Write a for loop to find the .json file in the directory and print its file path and when it was last accessed.
#
# os.path.getatime(path) is used to return when a path was last accessed.

# %%
#Start your code here

for file in os.listdir(directory):

  if file.lower().endswith(".json"):

    filename = os.path.basename(file)

    path = os.path.abspath(file)


    accessed = os.path.getatime(file)

    accessed_time = time.ctime(accessed)

    print("Filename: " + filename)

    print("Path: " + path)

    print("Last Accessed: " + accessed_time)
# Out:
# Filename: anscombe.json
# Path: /content/sample_data/anscombe.json
# Last Accessed: Sat Jan  1 08:00:00 2000

# %% [markdown]
# ##  CSV Library
#
# The CSV library enables you to read and write data in CSV format. We will be using this library to create a new CSV file and writing the metadata that we generated to this new file.

# %% [markdown]
# So we can read the metadata csv file, we will be borrow a couple of lines of code from the PANDAS library.

# %%
#import csv library
import csv

#import pandas and assign it as pd
import pandas as pd

#file_metadata.csv will be the file that we create in the current directory
# 'w' sets the file as writeable
with open('file_metadata.csv', 'w') as csvfile:

  #used to convert data into delimited strings on the given file
  csvwriter = csv.writer(csvfile)

  #Create a list of strings that represent the catogeries we collected
  rows = ['Filename', 'Path', 'Test']

  #write the rows the csv file
  csvwriter.writerow(rows)

test = pd.read_csv('file_metadata.csv')

test
# Out:
# Empty DataFrame
# Columns: [Filename, Path, Test]
# Index: []

# %%
#import csv library
import csv

#import pandas and assign it as pd
import pandas as pd

#file_metadata.csv will be the file that we create in the current directory
# 'w' sets the file as writeable
with open('file_metadata.csv', 'w') as csvfile:

  #used to convert data into delimited strings on the given file
  csvwriter = csv.writer(csvfile)

  #Create a list of strings that represent the catogeries we collected
  rows = ['Filename', 'Path', 'Size', "Created", "Modified", "Accessed"]

  #write the rows the csv file
  csvwriter.writerow(rows)

  #write for loop to process each file in directory
  for file in os.listdir(directory):

            #Find filename for file
            filename = os.path.basename(file)

            #Find file size in bytes
            path = os.path.abspath(file)

            filesize = os.path.getsize(file)

            creation = os.path.getctime(file)

            creation_time = time.ctime(creation)

            modified = os.path.getmtime(file)

            modified_time = time.ctime(modified)

            accessed = os.path.getatime(file)

            accessed_time = time.ctime(accessed)

            #write each variable in its corresponding row
            csvwriter.writerow([filename, path, filesize, creation_time, modified_time, accessed_time])


test = pd.read_csv('file_metadata.csv')

test
# Out:
#                        Filename  \
# 0                 anscombe.json
# 1                     README.md
# 2                mnist_test.CSV
# 3            .ipynb_checkpoints
# 4             file_metadata.csv
# 5  california_housing_train.csv
# 6         mnist_train_small.csv
# 7   california_housing_test.csv
#
#                                                 Path      Size  \
# 0                 /content/sample_data/anscombe.json      1697
# 1                     /content/sample_data/README.md       930
# 2                /content/sample_data/mnist_test.CSV  18289443
# 3            /content/sample_data/.ipynb_checkpoints      4096
# 4             /content/sample_data/file_metadata.csv         0
# 5  /content/sample_data/california_housing_train.csv   1706430
# 6         /content/sample_data/mnist_train_small.csv  36523880
# 7   /content/sample_data/california_housing_test.csv    301141
#
#                     Created                  Modified  \
# 0  Tue Aug 13 14:29:24 2024  Sat Jan  1 08:00:00 2000
# 1  Tue Aug 13 14:29:24 2024  Sat Jan  1 08:00:00 2000
# 2  Thu Aug 15 16:37:36 2024  Tue Aug 13 13:26:22 2024
# 3  Thu Aug 15 16:37:36 2024  Thu Aug 15 16:37:36 2024
# 4  Thu Aug 15 20:55:16 2024  Thu Aug 15 20:55:16 2024
# 5  Tue Aug 13 14:29:24 2024  Tue Aug 13 13:26:19 2024
# 6  Tue Aug 13 14:29:25 2024  Tue Aug 13 13:26:21 2024
# 7  Tue Aug 13 14:29:24 2024  Tue Aug 13 13:26:19 2024
#
#                    Accessed
# 0  Sat Jan  1 08:00:00 2000
# 1  Sat Jan  1 08:00:00 2000
# 2  Thu Aug 15 16:37:44 2024
# 3  Thu Aug 15 20:29:40 2024
# 4  Thu Aug 15 20:50:29 2024
# 5  Tue Aug 13 13:26:19 2024
# 6  Tue Aug 13 13:26:21 2024
# 7  Tue Aug 13 13:26:19 2024

# %% [markdown]
# ## Challenge
#
# Edit the above script to also record the size of each file and when they were created, last modified, and accessed.

# %%
#Start your code here
