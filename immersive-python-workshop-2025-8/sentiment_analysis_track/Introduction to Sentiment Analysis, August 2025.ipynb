# %% [markdown]
# First, we'll download and format our data.
# We are using a modified version of data sourced from this link: https://cseweb.ucsd.edu/~jmcauley/datasets/amazon_v2/
#
# Download the dataset we'll be using here: https://drive.google.com/file/d/1F-7T3erdExrqd0W-tiZMDT-0GPUdQ8kZ/view?usp=sharing
#
# ### If you run into a cetificate error with NLTK when running code locally, please try this workaround to download packages locally using the NLTK downloader (run this code in your local terminal, not in Colab):

# %%
# import nltk
# import ssl

# try:
#     _create_unverified_https_context = ssl._create_unverified_context
# except AttributeError:
#     pass
# else:
#     ssl._create_default_https_context = _create_unverified_https_context

# nltk.download('vader_lexicon')

# %% [markdown]
# ### Processing Data

# %%
# Processing Our Data

# First, import Pandas and JSON
import pandas as pd
import json

# Open the file, load it using the json package, then create a dataframe in Pandas using the json_normalize function.
file = open('sample_data/Software_array_small.json')
data = json.load(file)

df = pd.json_normalize(data)
print(df)
# Out:
#       overall  verified   reviewTime      reviewerID        asin  \
# 0         4.0     False  10 20, 2010  A38NELQT98S4H8  0321719816
# 1         4.0     False  10 18, 2010  A3QJU4FEN8PQSZ  0321719816
# 2         5.0     False  10 16, 2010   ACJT8MUC0LRF0  0321719816
# 3         5.0     False  10 12, 2010   AYUF7YETYOLNX  0321719816
# 4         5.0     False   10 7, 2010  A31ICLWQ9CSHRS  0321719816
# ...       ...       ...          ...             ...         ...
# 4994      3.0      True   03 4, 2011  A3GW8HX6UB0XML  B003YJ5DKG
# 4995      5.0      True   03 4, 2011  A3UEGYW49RUP1P  B003YJ5DKG
# 4996      1.0      True  02 12, 2011   A5JLAU2ARJ0BO  B003YJ5DKG
# 4997      4.0     False  01 18, 2011   ARX66NNKRP1YT  B003YJ5DKG
# 4998      1.0     False  01 12, 2011  A1REMEHU05QCWM  B003YJ5DKG
#
#           reviewerName                                         reviewText  \
# 0            WB Halper  I've been using Dreamweaver (and it's predeces...
# 1               Grimmy  The demo is done with the PC version, with ref...
# 2            D. Fowler  If you've been wanting to learn how to create ...
# 3         Bryan Newman  I've been creating websites with Dreamweaver f...
# 4           Al Swanson  I decided (after trying a number of other prod...
# ...                ...                                                ...
# 4994              Jeff  This is a typical Quicken Deluxe software that...
# 4995              Judy  Love the Quicken have owned 3 so far.\n\nThis ...
# 4996      Old-and-Wise  I know, giving a product one star because it f...
# 4997         Mercury52  Easy to use, setting up accounts for checking,...
# 4998  Elmer B. Fuddled  if i look over the history of quicken upgrades...
#
#                                                 summary  unixReviewTime  \
# 0                   A solid overview of Dreamweaver CS5      1287532800
# 1                                          A good value      1287360000
# 2     This is excellent software for those who want ...      1287187200
# 3     A Fantastic Overview of Dream Weaver and Web D...      1286841600
# 4                                  Excellent Tutorials!      1286409600
# ...                                                 ...             ...
# 4994                                Quicken Deluxe 2011      1299196800
# 4995      Quicken Deluxe 2011 (Purchased on 01/28/2011)      1299196800
# 4996   Cannot import Money file without Money installed      1297468800
# 4997                     Excellent For Money Management      1295308800
# 4998                      another "non-upgrade" upgrade      1294790400
#
#      style.Format: vote image style.Platform: style.Color: style.Size:  \
# 0          DVD-ROM  NaN   NaN             NaN          NaN         NaN
# 1          DVD-ROM  NaN   NaN             NaN          NaN         NaN
# 2          DVD-ROM    3   NaN             NaN          NaN         NaN
# 3          DVD-ROM  NaN   NaN             NaN          NaN         NaN
# 4          DVD-ROM  NaN   NaN             NaN          NaN         NaN
# ...            ...  ...   ...             ...          ...         ...
# 4994           NaN  NaN   NaN         PC Disc          NaN         NaN
# 4995           NaN  NaN   NaN         PC Disc          NaN         NaN
# 4996           NaN  NaN   NaN         PC Disc          NaN         NaN
# 4997           NaN  NaN   NaN         PC Disc          NaN         NaN
# 4998           NaN    3   NaN         PC Disc          NaN         NaN
#
#      style.Package Type:
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 4994                 NaN
# 4995                 NaN
# 4996                 NaN
# 4997                 NaN
# 4998                 NaN
#
# [4999 rows x 16 columns]

# %%
# Let's simplify our data by trimming the components of the dataframe we won't be using.
cleaned_df = df[['overall','summary','reviewText']]
print(cleaned_df)

# %% [markdown]
# ### Starting Out with Sentiment Analysis

# %%
# Starting Out with Sentiment Analysis

# import the Vader package from NLTK
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the lexicon used by Vader
import nltk
nltk.download('vader_lexicon')

# some minor pandas configuration
pd.options.mode.chained_assignment = None

# Loading our sentiment analyzer
sent_an = SentimentIntensityAnalyzer()

# A function that returns our Vader sentiment scores
# The compound score combines the score for the entire text we feed it (in this case, our reviews)
def vader_sentiment(text):
    return sent_an.polarity_scores(text)['compound']

# Create new column for the Vader compound sentiment score
cleaned_df['sentiment score'] = cleaned_df['reviewText'].apply(vader_sentiment)

# Categorize our sentiment values as positive, negative,or neutral based on specified score thresholds
def categorize_sentiment(sentiment, neg_threshold=-0.05, pos_threshold=0.05):
    if sentiment < neg_threshold:
        label = 'negative'
    elif sentiment > pos_threshold:
        label = 'positive'
    else:
        label = 'neutral'
    return label

# Create a new column in our dataframe based on our categorized sentiment scores
cleaned_df['sentiment classification'] = cleaned_df['sentiment score'].apply(categorize_sentiment)

print(cleaned_df)
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
#       overall                                            summary  \
# 0         4.0                A solid overview of Dreamweaver CS5
# 1         4.0                                       A good value
# 2         5.0  This is excellent software for those who want ...
# 3         5.0  A Fantastic Overview of Dream Weaver and Web D...
# 4         5.0                               Excellent Tutorials!
# ...       ...                                                ...
# 4994      3.0                                Quicken Deluxe 2011
# 4995      5.0      Quicken Deluxe 2011 (Purchased on 01/28/2011)
# 4996      1.0   Cannot import Money file without Money installed
# 4997      4.0                     Excellent For Money Management
# 4998      1.0                      another "non-upgrade" upgrade
#
#                                              reviewText  sentiment score  \
# 0     I've been using Dreamweaver (and it's predeces...           0.8134
# 1     The demo is done with the PC version, with ref...           0.9255
# 2     If you've been wanting to learn how to create ...           0.9995
# 3     I've been creating websites with Dreamweaver f...           0.9934
# 4     I decided (after trying a number of other prod...           0.9487
# ...                                                 ...              ...
# 4994  This is a typical Quicken Deluxe software that...          -0.5423
# 4995  Love the Quicken have owned 3 so far.\n\nThis ...           0.9442
# 4996  I know, giving a product one star because it f...          -0.9933
# 4997  Easy to use, setting up accounts for checking,...           0.9136
# 4998  if i look over the history of quicken upgrades...           0.2182
#
#      sentiment classification
# 0                    positive
# 1                    positive
# 2                    positive
# 3                    positive
# 4                    positive
# ...                       ...
# 4994                 negative
# 4995                 positive
# 4996                 negative
# 4997                 positive
# 4998                 positive
#
# [4999 rows x 5 columns]

# %% [markdown]
# Now, let's get the mean of our sentiment scores.

# %%
sentiment_mean = cleaned_df['sentiment score'].mean()
print(sentiment_mean)

# %% [markdown]
# And the counts for how many positive or negative reviews we found.

# %%
cleaned_df.groupby(['sentiment classification']).size().reset_index(name='count')
# Out:
#   sentiment classification  count
# 0                 negative    697
# 1                  neutral    156
# 2                 positive   4146

# %% [markdown]
# Now that we've performed sentiment analysis on our dataset, let's try a hands-on exercise to practice using Vader on a simple array of sentences. Try completing the code below to perform sentiment analysis on the list of five sentences.

# %%
# importing the necessary packages
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Loading our sentiment analyzer
sent_an = SentimentIntensityAnalyzer()

example_sentences = ["As I said above, if you're a novice, a relative newcomer or just an experienced web designer who wants a refresher course, this is a good way to do it.",
                     "Kinda dumb UI choice, initially confusing.",
                     "If you would like to dive into the publishing aspects and really optimizing your workflow, then this would be a good investment for you.",
                     "The exposition is clear, but perhaps a bit dry.",
                     "The software is well known and excellent."]

# your code here...

# %% [markdown]
# ### Answer

# %%
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Loading our sentiment analyzer
sent_an = SentimentIntensityAnalyzer()

# A function that returns our Vader sentiment scores
def vader_sentiment(text):
    return sent_an.polarity_scores(text)['compound']

example_sentences = ["As I said above, if you're a novice, a relative newcomer or just an experienced web designer who wants a refresher course, this is a good way to do it.",
                     "Kinda dumb UI choice, initially confusing.",
                     "If you would like to dive into the publishing aspects and really optimizing your workflow, then this would be a good investment for you.",
                     "The exposition is clear, but perhaps a bit dry.",
                     "The software is well known and excellent."]

for sent in example_sentences:
  sentiment_eval = vader_sentiment(sent)
  print(sent, sentiment_eval)

# %% [markdown]
# ### TextBlob

# %%
# TextBlob

# First, install the package.
# !pip install textblob

# %% [markdown]
# TextBlob's sentiment property returns a named tuple of the form Sentiment(polarity, subjectivity). The polarity score is a float within the range [-1.0, 1.0], with -1 being a negative sentiment and 1 being positive. The subjectivity is a float within the range [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective.
#
# First, let's try out the package on a simple sample sentence.

# %%
# importing the package
from textblob import TextBlob

testimonial1 = TextBlob("Textblob is amazingly simple to use. What great fun!")

testimonial2 = TextBlob("Textblob is horrendous. What a terrible package!")

print("Testimonial 1:")
print(testimonial1.sentiment)
print(testimonial1.sentiment.polarity)
print("\n")
print("Testimonial 2:")
print(testimonial2.sentiment)
print(testimonial2.sentiment.subjectivity)
# Out:
# Testimonial 1:
# Sentiment(polarity=0.39166666666666666, subjectivity=0.4357142857142857)
# 0.39166666666666666
#
#
# Testimonial 2:
# Sentiment(polarity=-1.0, subjectivity=1.0)
# 1.0

# %% [markdown]
# Next, we can use the sentiment_assessments feature to get additional details about the text after applying sentiment analysis to it.  The sentiment_assessments feature allows us to return data about the sentence  in the form (polarity, subjectivity, assessments), where assessments is a list of polarity and subjectivity scores for the assessed tokens.

# %%
from textblob import TextBlob

testimonial = TextBlob("Textblob is amazingly simple to use. What great fun!")

print("Subjectivity score: " + str(testimonial.sentiment_assessments.subjectivity))
print(testimonial.sentiment_assessments)
# Out:
# Subjectivity score: 0.4357142857142857
# Sentiment(polarity=0.39166666666666666, subjectivity=0.4357142857142857, assessments=[(['amazingly', 'simple'], 0.0, 0.35714285714285715, None), (['great'], 0.8, 0.75, None), (['fun', '!'], 0.375, 0.2, None)])

# %% [markdown]
# Finally, let's try applying TextBlob to the text in our dataframe. This is our second hands-on exercise--try to complete the code below to use Text Blob for sentiment analysis on our reviewText column, like we did with Vader earlier.

# %%
# A function that returns our Text Blob sentiment scores
def textblob_sentiment(text):
    tb_sentiment = TextBlob(text)
    return tb_sentiment.sentiment.polarity

# Create a new column for the Text Blob compound sentiment score
cleaned_df['text blob sentiment score'] = cleaned_df['reviewText'].apply(textblob_sentiment)

# Your code here...

# %% [markdown]
# ### Answer

# %%
from textblob import TextBlob

# A function that returns our Text Blob sentiment scores
def textblob_sentiment(text):
    tb_sentiment = TextBlob(text)
    return tb_sentiment.sentiment.polarity

# Create a new column for the Text Blob compound sentiment score
cleaned_df['text blob sentiment score'] = cleaned_df['reviewText'].apply(textblob_sentiment)

# Categorize our sentiment values as positive, negative,or neutral based on specified score thresholds
def categorize_sentiment(sentiment, neg_threshold=-0.05, pos_threshold=0.05):
    if sentiment < neg_threshold:
        label = 'negative'
    elif sentiment > pos_threshold:
        label = 'positive'
    else:
        label = 'neutral'
    return label

# Create a new column in our dataframe based on our categorized sentiment scores
cleaned_df['text blob sentiment classification'] = cleaned_df['text blob sentiment score'].apply(categorize_sentiment)

print(cleaned_df)
# Out:
#       overall                                            summary  \
# 0         4.0                A solid overview of Dreamweaver CS5
# 1         4.0                                       A good value
# 2         5.0  This is excellent software for those who want ...
# 3         5.0  A Fantastic Overview of Dream Weaver and Web D...
# 4         5.0                               Excellent Tutorials!
# ...       ...                                                ...
# 4994      3.0                                Quicken Deluxe 2011
# 4995      5.0      Quicken Deluxe 2011 (Purchased on 01/28/2011)
# 4996      1.0   Cannot import Money file without Money installed
# 4997      4.0                     Excellent For Money Management
# 4998      1.0                      another "non-upgrade" upgrade
#
#                                              reviewText  sentiment score  \
# 0     I've been using Dreamweaver (and it's predeces...           0.8134
# 1     The demo is done with the PC version, with ref...           0.9255
# 2     If you've been wanting to learn how to create ...           0.9995
# 3     I've been creating websites with Dreamweaver f...           0.9934
# 4     I decided (after trying a number of other prod...           0.9487
# ...                                                 ...              ...
# 4994  This is a typical Quicken Deluxe software that...          -0.5423
# 4995  Love the Quicken have owned 3 so far.\n\nThis ...           0.9442
# 4996  I know, giving a product one star because it f...          -0.9933
# 4997  Easy to use, setting up accounts for checking,...           0.9136
# 4998  if i look over the history of quicken upgrades...           0.2182
#
#      sentiment classification  text blob sentiment score  \
# 0                    positive                   0.232701
# 1                    positive                   0.013317
# 2                    positive                   0.193658
# 3                    positive                   0.258266
# 4                    positive                   0.266241
# ...                       ...                        ...
# 4994                 negative                   0.139167
# 4995                 positive                   0.375000
# 4996                 negative                  -0.059543
# 4997                 positive                   0.391667
# 4998                 positive                   0.062500
#
#      text blob sentiment classification
# 0                              positive
# 1                               neutral
# 2                              positive
# 3                              positive
# 4                              positive
# ...                                 ...
# 4994                           positive
# 4995                           positive
# 4996                           negative
# 4997                           positive
# 4998                           positive
#
# [4999 rows x 7 columns]

# %% [markdown]
# ### Training Our Own Classifier

# %%
# Finally, let's see what it looks like to train our own sentiment classifier.
# This can be especially useful when working with highly specific data or non-English languages.

# imports
import nltk
from nltk import word_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')

# Grouping together reviews classified as positive by TextBlob
tb_grouped_df = cleaned_df.groupby('text blob sentiment classification')
tb_pos_group = tb_grouped_df.get_group('positive')

# First, we provide our training data as a list of sentences and their sentiment classifications:
training_data = [("It's practical to hope because the hope is for us to survive as a human species.", "pos"),
          ("Italy's soccer players were unlucky to find themselves in a qualifying group with Spain", "neg"),
          ("Instead, root for the Knights whose fans are childlike in their glee.", "pos"),
          ("The overwhelming perception is that the European Union has done very little to alleviate this specifically Italian difficulty.", "neg"),
          ("We are in for a period of painful social conflict, at the end of which perhaps we may remember why it once seemed wise to relegate certain emotions to the stadium.", "neg"),
          ("The heartlessness of that is mind-boggling.", "neg"),
          ("My father was an insatiable learner with intelligence that his baby brother once told me bordered on genius.", "pos"),
        ]

training_data_2 = [("This software was exactly what I was looking for. Absolutely perfect.", "pos"),
          ("I had an absolutely horrendous experience trying to troubleshoot this program.", "neg"),
          ("The releases from this company never fail to dissapoint. Wonderful product!", "pos"),
          ("I will never purchase anything from this company again. Terrible customer support.", "neg"),
          ("Everything about this product screams half-baked.", "neg"),
          ("The attention to detail and care put into their products is phenomenal.", "pos"),
          ("This newest release is absolutely genius.", "pos"),
        ]

# Training NLTK's Naïve Bayes Classifier with a dictionary created from our list
dictionary = set(word.lower() for passage in training_data_2 for word in word_tokenize(passage[0]))

t = [({word: (word in word_tokenize(x[0])) for word in dictionary}, x[1]) for x in training_data_2]

classifier = nltk.NaiveBayesClassifier.train(t)

# Let's test out our new classifier on a small sample of our positive reviews:
random_pos_sample_2 = tb_pos_group.sample(10)
sample_texts = random_pos_sample_2['reviewText']

# Looping through our list of reviews and outputting the classifier's assessments.
for s in sample_texts:
    test_data = s
    test_data_features = {word.lower(): (word in word_tokenize(test_data.lower())) for word in dictionary}

    print(s[:100])
    print("Classification: " + classifier.classify(test_data_features))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# This program has a wonderfully inventive menu system for accessing tools.  This unique interface sys
# Classification: neg
# Work perfectly with my hackintosh
# Classification: pos
# Roxio Toast 7
#
# Company: Roxio
#
# Price: $99
#
# [...]
#
# We here at MyMac.com have been reviewing Roxio Toa
# Classification: pos
# I did my 100th upgrade to Windows XP Pro today, for a new client.  All 100 installations went smooth
# Classification: pos
# I have used "Instant Immersion Spanish Levels 1,2 & 3" for several months now and it is a complete S
# Classification: neg
# A great little hub for those of us still wired to each other, very fast, no set up issues, just plug
# Classification: pos
# Can't beat this software for doing your taxes. It is used by many tax firms as well. I have used it
# Classification: pos
# I wanted an easy way to learn spanish so that I could talk to my neighbors and some co-workers who p
# Classification: pos
# Acronis True Image simply does not work.  Mine freezes up with every backup.  At lockup it uses 100
# Classification: neg
# I've lived with this operating system for awhile and I have grown to like it. It is much faster and
# Classification: pos

# %%
# Now, let's visualize our data

# Import the matplotlib library
import matplotlib.pyplot as plt
# import numpy as np
import matplotlib.ticker as ticker

# Specify the details of our desired plot
plt.figure(figsize=(12,12))

# creating the figure and single axis
fig,ax = plt.subplots()

# setting the limit for the y-axis
plt.ylim(0, 20)

# creating the graph

# rounding our sentiment values to the nearest 0.05 for cleaner graphing
df_rounded = (cleaned_df['sentiment score'] * 20).round() / 20
graph_image = df_rounded.sample(n=200).value_counts().plot(kind='bar', ylabel='frequency')

# save the file

from google.colab import files
plt.savefig("example.png")
files.download("example.png")

# displaying the figure
plt.show()

# %%
# Let's try another visualization where we look at a smaller subset of our data
# We'll get a random sample of 50 entries in our dataframe and plot those

# Taking our sample
random_sample = cleaned_df.sample(50)
print(random_sample)

# Specifying our plot details again
plt.figure(figsize=(8,8))
fig,ax = plt.subplots()
random_sample['sentiment classification'].value_counts().plot(ax = ax, kind = 'bar', ylabel = 'frequency')
plt.show()
# Out:
#       overall                                            summary  \
# 2135      5.0                           Great for the home user.
# 4385      3.0                                An average software
# 4472      4.0        Great antivirus software for a great price!
# 74        3.0  Solid estate planning product, but living trus...
# 3262      5.0                                iPhoto re-installed
# 2957      1.0                                  NO VBA!!!!!!!!!!!
# 4971      5.0                                            Thanks.
# 377       5.0                             Bluetooth Access Point
# 1284      5.0                        Router, that will help you!
# 1041      5.0                                         Five Stars
# 1565      5.0                                     360 all around
# 1276      5.0                             Bluetooth Access Point
# 3761      5.0                        I really like this product!
# 2605      5.0                                         Five Stars
# 4012      4.0                         Good Software - High Price
# 2327      5.0                                         Five Stars
# 4998      1.0                      another "non-upgrade" upgrade
# 3666      5.0                                        no problems
# 3129      4.0                                 Purely Surround-ed
# 1381      5.0                                     Price not high
# 548       5.0        A wonderful (but pricey) Microsoft product.
# 2927      4.0                                        Worked Well
# 1644      3.0                       A resource hog but effective
# 2852      5.0                           Great story, fun puzzles
# 3620      4.0                 So many options, so little time...
# 3281      4.0     Good Product - satisfied with customer support
# 1265      5.0                                Worked as expected.
# 1589      1.0                        Overpriced and Underpowered
# 1461      1.0                                          Get a Mac
# 2625      5.0  and a great price. Way cheaper from this selle...
# 1003      4.0                                        No problems
# 4970      2.0                                          Two Stars
# 2062      2.0                     Less Features, More Cumbersome
# 2449      4.0                      Changes keep you buying stuff
# 4564      4.0                  Good for certain things, not all.
# 3328      3.0                                   READ THIS FIRST!
# 1107      5.0  and a great price. Way cheaper from this selle...
# 2378      3.0                     works well, but poor interface
# 4303      4.0                        A Good Choice for the Money
# 680       5.0  Flawless and easy setup and perfect performanc...
# 3834      3.0                            Limited Data protection
# 2144      1.0          Far Inferior to Windows Version of Office
# 2724      5.0                         cheap, worked like a charm
# 4286      1.0  Not $120 better then Vista, and buy OEM if you...
# 4786      3.0                              Probably not the best
# 4105      4.0                  Pretty Good.... But Still Lacking
# 1202      5.0                                              great
# 1000      1.0                                  Miserable product
# 2815      5.0                                            General
# 331       5.0  Excellent device; if you buy one USB hub, this...
#
#                                              reviewText  sentiment score  \
# 2135  I'm a recent convert to the Mac and I was want...           0.9365
# 4385  I am a cautious Internet user and most of time...          -0.8994
# 4472  I've been using AVG Free for a couple years no...           0.9911
# 74    This is the third version of Quicken Willmaker...           0.9973
# 3262  After doing a clean installation, I found that...           0.1280
# 2957  Apparently Bill Gates thinks we haven't suffer...          -0.7839
# 4971                                            Thanks.           0.4404
# 377   Have it plugged into my wan/router so people v...           0.2023
# 1284  I have owned this router for about 1 month. Wh...           0.9941
# 1041                           EXCELLANT - GREAT SELLER           0.6249
# 1565  I was first introduced to 360 as a beta tester...           0.8625
# 1276  Have it plugged into my wan/router so people v...           0.2023
# 3761  NAV 2009 is so much faster than previous versi...           0.8847
# 2605  Great price from a company that also provides ...           0.7783
# 4012  Corel Painter 11 is a somewhat souped-up versi...           0.9839
# 2327  I miss Outlook but this is a good replacement ...           0.5499
# 4998  if i look over the history of quicken upgrades...           0.2182
# 3666  Installation was easy and it seems to be doing...           0.4404
# 3129  Symantec's 360 has a surprisingly excellent pr...           0.9799
# 1381  The upgrades for Vista are relatively cheap, e...          -0.1531
# 548   I really like this new version of Microsoft Of...           0.9960
# 2927  I was initially hesitant to purchase this inst...          -0.7906
# 1644  As I write this review McAfee is using approxi...           0.9948
# 2852  This game is a combination hidden-object/brain...           0.9676
# 3620  Right now, there are a pleethora of options fo...           0.4972
# 3281  I have used the plain vanilla version of spysw...           0.9451
# 1265  Easy to install on XP machine, drivers worked ...           0.9190
# 1589  I was excited about getting and reviewing this...           0.9680
# 1461  Windows is so slow  and dorky...why not try a ...           0.6249
# 2625  Item came quickly, exactly as described, and a...           0.8479
# 1003  Unlike your other reviewers I downloaded and i...           0.5267
# 4970  Computer crashed after a month and wasn't able...           0.0000
# 2062  Very little change, less features (does not su...           0.8244
# 2449  I have been using apple computers for many yea...           0.9152
# 4564  I already wrote a review for Parallels, and it...           0.9979
# 3328  There is a lengthy list of system requirements...           0.9926
# 1107  Item came quickly, exactly as described, and a...           0.8479
# 2378  I've used windvd for a lot of years, mainly be...           0.3629
# 4303  I have been a long time user of Norton Anti Vi...          -0.0129
# 680   It was amazingly easy to set up for a person l...           0.9007
# 3834  First, the limitations:\n\nThis product does n...           0.9699
# 2144  Office 2008 for the Mac has been out over a ye...          -0.4272
# 2724  Installed in new Win 7 machine where I needed ...           0.8225
# 4286  First, it took me three tries to get the upgra...           0.7724
# 4786  Because I possess neither the skill nor the ab...           0.9891
# 4105  This Vipre Antivirus software has some really ...           0.9909
# 1202  Once my IT expert set it up the NAS has run fl...           0.8309
# 1000  I had Norton Internet Security 2005 on my PC f...          -0.7004
# 2815  I have been a beta tester for Quicken (Windows...           0.6997
# 331   Power and layout are the two big advantages to...           0.9803
#
#      sentiment classification  text blob sentiment score  \
# 2135                 positive                   0.292045
# 4385                 negative                   0.101515
# 4472                 positive                   0.264015
# 74                   positive                   0.058819
# 3262                 positive                  -0.066667
# 2957                 negative                   0.033359
# 4971                 positive                   0.200000
# 377                  positive                   0.354167
# 1284                 positive                   0.375694
# 1041                 positive                   0.800000
# 1565                 positive                   0.208333
# 1276                 positive                   0.354167
# 3761                 positive                  -0.154167
# 2605                 positive                   0.400000
# 4012                 positive                   0.219074
# 2327                 positive                   0.700000
# 4998                 positive                   0.062500
# 3666                 positive                   0.138889
# 3129                 positive                   0.219856
# 1381                 negative                   0.112500
# 548                  positive                   0.232605
# 2927                 negative                   0.091548
# 1644                 positive                   0.203253
# 2852                 positive                   0.011893
# 3620                 positive                   0.152019
# 3281                 positive                   0.047762
# 1265                 positive                   0.527083
# 1589                 positive                   0.175161
# 1461                 positive                   0.212121
# 2625                 positive                   0.246667
# 1003                 positive                   0.081349
# 4970                  neutral                   0.500000
# 2062                 positive                   0.305655
# 2449                 positive                   0.330556
# 4564                 positive                   0.154887
# 3328                 positive                   0.225687
# 1107                 positive                   0.246667
# 2378                 positive                   0.105357
# 4303                  neutral                  -0.132702
# 680                  positive                   0.163690
# 3834                 positive                   0.047520
# 2144                 negative                   0.068196
# 2724                 positive                   0.347273
# 4286                 positive                   0.119242
# 4786                 positive                   0.227557
# 4105                 positive                   0.239141
# 1202                 positive                   0.571429
# 1000                 negative                  -0.102778
# 2815                 positive                   0.284091
# 331                  positive                   0.060802
#
#      text blob sentiment classification
# 2135                           positive
# 4385                           positive
# 4472                           positive
# 74                             positive
# 3262                           negative
# 2957                            neutral
# 4971                           positive
# 377                            positive
# 1284                           positive
# 1041                           positive
# 1565                           positive
# 1276                           positive
# 3761                           negative
# 2605                           positive
# 4012                           positive
# 2327                           positive
# 4998                           positive
# 3666                           positive
# 3129                           positive
# 1381                           positive
# 548                            positive
# 2927                           positive
# 1644                           positive
# 2852                            neutral
# 3620                           positive
# 3281                            neutral
# 1265                           positive
# 1589                           positive
# 1461                           positive
# 2625                           positive
# 1003                           positive
# 4970                           positive
# 2062                           positive
# 2449                           positive
# 4564                           positive
# 3328                           positive
# 1107                           positive
# 2378                           positive
# 4303                           negative
# 680                            positive
# 3834                            neutral
# 2144                           positive
# 2724                           positive
# 4286                           positive
# 4786                           positive
# 4105                           positive
# 1202                           positive
# 1000                           negative
# 2815                           positive
# 331                            positive

# %% [markdown]
# For our third hands-on exercise, try to create your own plot using the sentiment scores we generated using Text Blob.

# %%
# Import the matplotlib library
import matplotlib.pyplot as plt

# your code here...

# %% [markdown]
# ### Answer

# %%
# Import the matplotlib library
import matplotlib.pyplot as plt

# Specify the details of our desired plot
plt.figure(figsize=(12,12))
fig,ax = plt.subplots()
#plt.xlim(0, 5)  # X-axis range from 0 to 5
plt.ylim(0, 6) # Y-axis range from 0 to 5
graph_image = cleaned_df['text blob sentiment score'].value_counts().plot(kind='bar', ylabel='frequency')
graph_image.axes.get_xaxis().set_visible(False)
plt.show()

# %% [markdown]
# ### More Visualization

# %%
# Now let's visualize the text itself
# We'll stick with a small, random sample of our data to keep things simple

# First, we create a new dataframe by grouping our data based on its sentiment classification.
# For this example, we'll only look at reviews classified as positive
grouped_df = cleaned_df.groupby('sentiment classification')
pos_group = grouped_df.get_group('positive')
random_pos_sample = pos_group.sample(50)
print(random_pos_sample)

# %%
# Now we'll create a wordcloud based on word frequencies in our positive reviews.
# First, we get the data ready for visualization...

# We remove punctuation from the dataframe using a regular expression
random_pos_sample['wcText'] = random_pos_sample['reviewText'].str.replace('[^\w\s]','')

print(random_pos_sample['wcText'])

# Next we remove the stopwords (these can be modified to include non-english languages)
nltk.download('stopwords')

from nltk.corpus import stopwords
stopwords = stopwords.words('english')
# You can add custom stopwords, as well:
# stopwords.append('example')

# Make all of the words in our 'Tokenized Text' column lowercase
random_pos_sample['wcText'] = random_pos_sample['wcText'].str.lower()

# A lambda function is a small, anonymous function.
# A lambda function can take any number of arguments, but can only have one expression.
# Here, we're joining the words not in the stopwords list into a single string.
# This prepares the text for tokenization.
random_pos_sample['wcText'] = random_pos_sample['wcText'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stopwords)]))


# Next, tokenize the text into words using NLTK
from nltk import word_tokenize
nltk.download('punkt')

random_pos_sample['wcText'] = random_pos_sample['wcText'].apply(word_tokenize)


# Now we can count the word frequencies in our "Tokenized Text" column
# We transform each element of a list-like to a row, replicating index values.
exploded_text = random_pos_sample['wcText'].explode()

word_counts = exploded_text.value_counts()

# Word cloud
from wordcloud import WordCloud

# Convert our exploded_text list to a string
wordcloud_string=(" ").join(exploded_text)

# Generate the word cloud
wordcloud = WordCloud(width = 1000, height = 500).generate(wordcloud_string)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.savefig("wordcloud"+".png", bbox_inches='tight') # removes extra whitespace around our figure
plt.show()
plt.close()
# Out:
# 2527    First of all, I must say that there is a gener...
# 111     This is a fairly typical learn by listening la...
# 4618    This isn't a software product I can recommend ...
# 890     I wrote a bad review of Panther because it was...
# 4927    IT's one of the few remaining programs availab...
# 4203    I'm using Win7Pro x64.  When it works, it work...
# 2210    Man, Ubuntu just keeps getting better! It's ea...
# 3276    In the past Ive used Norton, McAffee & Zone Al...
# 2920    I like this program - in general - much more t...
# 2940    This version of Office was designed for the Ma...
# 2061    I was new to Vista when I received my new lapt...
# 2997    I like the nice glass look and some of the new...
# 4940    I'm running QB 2008 which is decent. Each time...
# 4891    Kaspersky has long been the anti-virus program...
# 146     I've been a user of Dramatica since earlier ve...
# 290     I researched reviews, tech specs, drives for t...
# 1424    Twenty minutes ago, a senior engineer with adv...
# 4623    This product arrived a few days ago - I was ex...
# 4835    I use "Dragon Naturally Speaking Home 11" on m...
# 1042    I just this and office 2008, but prefer the ap...
# 1418    I purchased this program for my new Vista PC a...
# 4410    As a long time Photoshop User I had some strug...
# 4088    Drawing and sketching programs seem to fall in...
# 4877    I use Kaspersky Anti-Virus 2011 3 user. on all...
# 2623    I give it a 5 star because it did increase ran...
# 1361    I will definitely NOT buy this product.  I ref...
# 4351    I tried the competitors' products, most notabl...
# 168     You can't go wrong with this device.  It's the...
# 2720    Once my IT expert set it up the NAS has run fl...
# 435     I may be going out on a limb here, but Windows...
# 1484    I just got a nasty virus on my XP powered comp...
# 4697    I work part time in the summer and fall for a ...
# 3054    This program is a let down after Apple's much ...
# 3592    This is an ok product.  I work with antivirus ...
# 3603    This is a good easy to use software for your s...
# 3545    I've been working with Snow Leopard since abou...
# 3789    Norton Antivirus 2009 is one of the best antiv...
# 160     "Message" is the first Nancy Drew Pc game that...
# 3594    I'll start off by stating the installation of ...
# 3517    Approximately 3 months of usage now and going ...
# 3626    Bitdefender works really well on both vista an...
# 3288    There is a lot to like in this this small and ...
# 973     Herinteractive! has done an outstanding job on...
# 38      The only real question is - does this card wor...
# 4613                                        great product
# 1582    As has been noted by other reviewers, Crunch w...
# 3079    Bento is not a pro's database. If you expect t...
# 4721                                                 good
# 877     Did what I wanted to do, could be more user fr...
# 1478    Do you need a basic but .docx/.xlsx/.pptx capa...
# Name: wcText, dtype: object
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
