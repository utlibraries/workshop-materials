# %% [markdown]
# # Hands-on Exercise #1
#
# In a Python file on your own computer, complete the following script to perform sentiment analysis using Vader on a sample of five sentences and print the results.

# %%
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Loading our sentiment analyzer
sent_an = SentimentIntensityAnalyzer()

example_sentences = ["As I said above, if you're a novice, a relative newcomer or just an experienced web designer who wants a refresher course, this is a good way to do it.",
                     "Kinda dumb UI choice, initially confusing.",
                     "If you would like to dive into the publishing aspects and really optimizing your workflow, then this would be a good investment for you.",
                     "The exposition is clear, but perhaps a bit dry.",
                     "The software is well known and excellent."]

# A function that returns our Vader sentiment scores
def vader_sentiment(text):
    return sent_an.polarity_scores(text)['compound']

for sent in example_sentences:
  sentiment_eval = vader_sentiment(sent)
  print(sent, sentiment_eval)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1146960749.py in <cell line: 0>()
#       1 import nltk
# ----> 2 nltk.download('vader_lexicon')
#       3
#       4 from nltk.sentiment.vader import SentimentIntensityAnalyzer
#       5
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to)
#     772                 )
#     773
# --> 774             for msg in self.incr_download(info_or_id, download_dir, force):
#     775                 # Error messages
#     776                 if isinstance(msg, ErrorMessage):
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in incr_download(self, info_or_id, download_dir, force)
#     627         # Look up the requested collection or package.
#     628         try:
# --> 629             info = self._info_or_id(info_or_id)
#     630         except (OSError, ValueError) as e:
#     631             yield ErrorMessage(None, f"Error loading {info_or_id}: {e}")
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in _info_or_id(self, info_or_id)
#     601     def _info_or_id(self, info_or_id):
#     602         if isinstance(info_or_id, str):
# --> 603             return self.info(info_or_id)
#     604         else:
#     605             return info_or_id
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in info(self, id)
#    1004         """Return the ``Package`` or ``Collection`` record for the
#    1005         given item."""
# -> 1006         self._update_index()
#    1007         if id in self._packages:
#    1008             return self._packages[id]
#
# /usr/local/lib/python3.11/dist-packages/nltk/downloader.py in _update_index(self, url)
#     946
#     947         # Download the index file.
# --> 948         self._index = nltk.internals.ElementWrapper(
#     949             ElementTree.parse(urlopen(self._url)).getroot()
#     950         )
#
# AttributeError: module 'nltk' has no attribute 'internals'

# %% [markdown]
# # Hands-on Exercise #2 - Text Blob

# %%
from textblob import TextBlob

# A function that returns our Text Blob sentiment scores
def textblob_sentiment(text):
    tb_sentiment = TextBlob(text)
    return tb_sentiment.sentiment.polarity

# Create a new column for the Text Blob compound sentiment score
cleaned_df['text blob sentiment score'] = cleaned_df['reviewText'].apply(textblob_sentiment)

# Categorize our sentiment values as positive, negative,or neutral based on specified score thresholds
def categorize_sentiment(sentiment, neg_threshold=-0.05, pos_threshold=0.05):
    if sentiment < neg_threshold:
        label = 'negative'
    elif sentiment > pos_threshold:
        label = 'positive'
    else:
        label = 'neutral'
    return label

# Create a new column in our dataframe based on our categorized sentiment scores
cleaned_df['text blob sentiment classification'] = cleaned_df['text blob sentiment score'].apply(categorize_sentiment)

print(cleaned_df)

# %% [markdown]
# # Hands-on Exercise 3
#
# Create your own plot of our Text Blob data using matplotlib.

# %%
# Import the matplotlib library
import matplotlib.pyplot as plt

# Specify the details of our desired plot
plt.figure(figsize=(12,12))
fig,ax = plt.subplots()
#plt.xlim(0, 5)  # X-axis range from 0 to 5
plt.ylim(0, 6) # Y-axis range from 0 to 5
graph_image = cleaned_df['text blob sentiment score'].value_counts().plot(kind='bar', ylabel='frequency')
graph_image.axes.get_xaxis().set_visible(False)
plt.show()
